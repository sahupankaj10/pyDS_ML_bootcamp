# %% [markdown]
# # Pandas built in DV features

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('../../data/my_csv.csv', index_col=0, low_memory=False)
df1.head()
# Out:
#                  Y      W       R      L      K
# YEAR
# 1948.000008  1.214  0.243  0.1454  1.415  0.612
# 1949.000008  1.354  0.260  0.2181  1.384  0.559
# 1950.000000  1.569  0.278  0.3157  1.388  0.573
# 1951.000000  1.948  0.297  0.3940  1.550  0.564
# 1952.000000  2.265  0.310  0.3559  1.802  0.574

# %%
df1['Y'].hist()

# %%
df1['Y'].hist(bins=30)

# %% [markdown]
# ### creating histogram through plot

# %%
df1['Y'].plot(kind="hist", bins=30)

# %%
df1['Y'].plot.hist(bins=30)

# %%
# show area
df1.plot.area(alpha=0.4)

# %%
# show bar plot
df1.plot.bar(stacked=True)

# %%
# show line plot
df1.plot.line(x=df1.index, y='K', figsize=(12,3), lw=1)

# %%
#scatter plot
df1.plot.scatter(x='Y', y='W', c='K', cmap='coolwarm') # df1.plot.scatter(x='Y', y='W', s=df1['K']*10)

# %%
df1.plot.box(by='K', cmap='coolwarm')

# %%
# hex plot
df = pd.DataFrame(np.random.rand(1000, 2), columns=('A', 'B'))

# %%
df.plot.hexbin(x='A', y='B', gridsize=25, cmap='coolwarm')

# %%
# kernal density plot
df.plot.density()
